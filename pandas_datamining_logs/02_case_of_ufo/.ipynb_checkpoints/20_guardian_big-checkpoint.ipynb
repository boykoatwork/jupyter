# %% [markdown]
# ![x-files](Thexfiles.jpg)
#
# In this example, [API guardian](https://open-platform.theguardian.com) documentation is used, which can be viewed at the following link.
#
# https://open-platform.theguardian.com/documentation/
#
# Example of API request:
#
# https://content.guardianapis.com/search?q=debate%20AND%20economy&tag=politics/politics&from-date=2014-01-01&api-key=test

# %%
import requests
import json

# %%
api_url = 'http://content.guardianapis.com/#/search?q=Ukraine'

# %%
payload = {
        'api-key':              '25ce3607-2201-4dac-9ccb-d887c3784d5e',
        'page-size':            200,
        'show-editors-picks':   'true',
        'show-elements':        'image',
        'show-fields':          'all'

}

# %%
response = requests.get(api_url, params=payload)

# %%
data = response.json()

# %%
data
# Out:
# {'response': {'status': 'ok',
#   'userTier': 'developer',
#   'total': 1,
#   'editorsPicks': []}}

# %%
response.json()
# Out:
# {'response': {'status': 'ok',
#   'userTier': 'developer',
#   'total': 1,
#   'editorsPicks': []}}

# %%
url = 'https://content.guardianapis.com/search'
payload = {'order-by': 'oldest', 'q': 'UFO', 'api-key': '25ce3607-2201-4dac-9ccb-d887c3784d5e'}

# %%
payload['page-size'] = 100
payload['page'] = 1

r = requests.get(url, payload)
j = json.loads(r.text)


N = int(j['response']['pages'])

# %%
N
# Out:
# 13

# %%
all = []


for k in range(N):
    payload['page'] = k + 1
    r = requests.get(url, payload)
    j = json.loads(r.text)
    s = j['response']['results']
    all.extend(s)

# %%
len(all)
# Out:
# 1263

# %%
import pandas as pd

# %%
df = pd.DataFrame(all)

# %%
df['webPublicationDate'] = pd.to_datetime(df['webPublicationDate'])

# %%
df.sort_values(by = ['webPublicationDate'], ascending=False)
# Out:
#                                                      id      type sectionId  \
# 1262  music/2021/oct/05/tresor-stays-relevant-30-yea...   article     music
# 1261  sport/live/2021/sep/19/england-v-new-zealand-s...  liveblog     sport
# 1260  world/2021/sep/12/what-i-saw-that-night-was-re...   article     world
# 1259  culture/2021/sep/11/homebody-or-hellraiser-our...   article   culture
# 1258  news/2021/sep/07/disastrous-voyage-satoshi-cry...   article      news
# ...                                                 ...       ...       ...
# 4                                      uk/1999/mar/20/4   article   uk-news
# 3         society/1999/mar/17/guardiansocietysupplement   article   society
# 2              media/1999/jan/25/tvandradio.television1   article   culture
# 1                 theguardian/1998/dec/31/features11.g2   article    global
# 0                                      uk/1989/jun/14/2   article   uk-news
#
#      sectionName        webPublicationDate  \
# 1262       Music 2021-10-05 14:58:13+00:00
# 1261       Sport 2021-09-19 17:28:11+00:00
# 1260  World news 2021-09-12 10:00:50+00:00
# 1259     Culture 2021-09-11 07:00:19+00:00
# 1258        News 2021-09-07 05:00:21+00:00
# ...          ...                       ...
# 4        UK news 1999-03-20 04:06:49+00:00
# 3        Society 1999-03-17 02:26:08+00:00
# 2        Culture 1999-01-25 04:17:17+00:00
# 1         Global 1998-12-31 04:21:18+00:00
# 0        UK news 1989-06-14 10:26:21+00:00
#
#                                                webTitle  \
# 1262  ‘No established disco would have played this m...
# 1261  England beat New Zealand by 13 runs (D/L) in s...
# 1260  ‘What I saw that night was real’: is it time t...
# 1259  Homebody or hellraiser: Our autumn arts previe...
# 1258  The disastrous voyage of Satoshi, the world’s ...
# ...                                                 ...
# 4                                  Pity the poor aliens
# 3                                         Cover stories
# 2                                        Watching brief
# 1                                   They came from Kent
# 0                   Guardian Tomorrows: Toxicity on tap
#
#                                                  webUrl  \
# 1262  https://www.theguardian.com/music/2021/oct/05/...
# 1261  https://www.theguardian.com/sport/live/2021/se...
# 1260  https://www.theguardian.com/world/2021/sep/12/...
# 1259  https://www.theguardian.com/culture/2021/sep/1...
# 1258  https://www.theguardian.com/news/2021/sep/07/d...
# ...                                                 ...
# 4          https://www.theguardian.com/uk/1999/mar/20/4
# 3     https://www.theguardian.com/society/1999/mar/1...
# 2     https://www.theguardian.com/media/1999/jan/25/...
# 1     https://www.theguardian.com/theguardian/1998/d...
# 0          https://www.theguardian.com/uk/1989/jun/14/2
#
#                                                  apiUrl  isHosted  \
# 1262  https://content.guardianapis.com/music/2021/oc...     False
# 1261  https://content.guardianapis.com/sport/live/20...     False
# 1260  https://content.guardianapis.com/world/2021/se...     False
# 1259  https://content.guardianapis.com/culture/2021/...     False
# 1258  https://content.guardianapis.com/news/2021/sep...     False
# ...                                                 ...       ...
# 4     https://content.guardianapis.com/uk/1999/mar/20/4     False
# 3     https://content.guardianapis.com/society/1999/...     False
# 2     https://content.guardianapis.com/media/1999/ja...     False
# 1     https://content.guardianapis.com/theguardian/1...     False
# 0     https://content.guardianapis.com/uk/1989/jun/14/2     False
#
#           pillarId pillarName
# 1262   pillar/arts       Arts
# 1261  pillar/sport      Sport
# 1260   pillar/news       News
# 1259   pillar/arts       Arts
# 1258   pillar/news       News
# ...            ...        ...
# 4      pillar/news       News
# 3      pillar/news       News
# 2      pillar/arts       Arts
# 1              NaN        NaN
# 0      pillar/news       News
#
# [1263 rows x 11 columns]

# %%
# !rm ufo_guardian.db

# %%
import sqlite3
conn = sqlite3.connect('ufo_guardian.db')

# %%
df.to_sql('ufo_guardian',con = conn)

# %%
conn.close()

# %% [markdown]
# You can open the saved database using CLI `sqlite3` or `sqlitebrowser`:
#
# ![](sqlite2.png)

# %% [markdown]
# ![Якщо треба - можно звернутись до sqlitebrowser](sqlite1.png)
#
# But we will use the pandas built-in tools:

# %%
df.describe(datetime_is_numeric=True)
# Out:
#                       id     type sectionId sectionName  \
# count               1263     1263      1263        1263
# unique              1263        6        39          39
# top     uk/1989/jun/14/2  article     music       Music
# freq                   1     1222       218         218
# mean                 NaN      NaN       NaN         NaN
# min                  NaN      NaN       NaN         NaN
# 25%                  NaN      NaN       NaN         NaN
# 50%                  NaN      NaN       NaN         NaN
# 75%                  NaN      NaN       NaN         NaN
# max                  NaN      NaN       NaN         NaN
#
#                          webPublicationDate                 webTitle  \
# count                                  1263                     1263
# unique                                  NaN                     1217
# top                                     NaN  Clubs picks of the week
# freq                                    NaN                       27
# mean    2011-03-18 15:29:52.016626944+00:00                      NaN
# min               1989-06-14 10:26:21+00:00                      NaN
# 25%               2007-03-27 09:01:19+00:00                      NaN
# 50%               2011-04-05 21:30:01+00:00                      NaN
# 75%               2015-11-03 03:47:38+00:00                      NaN
# max               2021-10-05 14:58:13+00:00                      NaN
#
#                                               webUrl  \
# count                                           1263
# unique                                          1263
# top     https://www.theguardian.com/uk/1989/jun/14/2
# freq                                               1
# mean                                             NaN
# min                                              NaN
# 25%                                              NaN
# 50%                                              NaN
# 75%                                              NaN
# max                                              NaN
#
#                                                    apiUrl isHosted  \
# count                                                1263     1263
# unique                                               1263        1
# top     https://content.guardianapis.com/uk/1989/jun/14/2    False
# freq                                                    1     1263
# mean                                                  NaN      NaN
# min                                                   NaN      NaN
# 25%                                                   NaN      NaN
# 50%                                                   NaN      NaN
# 75%                                                   NaN      NaN
# max                                                   NaN      NaN
#
#            pillarId pillarName
# count          1234       1234
# unique            5          5
# top     pillar/arts       Arts
# freq            555        555
# mean            NaN        NaN
# min             NaN        NaN
# 25%             NaN        NaN
# 50%             NaN        NaN
# 75%             NaN        NaN
# max             NaN        NaN

# %% [markdown]
# https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html

# %%
df[df['sectionId'] == 'news']
# Out:
#                                                      id     type sectionId  \
# 27    theguardian/2000/jan/12/correctionsandclarific...  article      news
# 115                 news/2002/may/30/guardianobituaries  article      news
# 193                news/2004/may/20/guardianobituaries1  article      news
# 216   theguardian/2005/jan/31/correctionsandclarific...  article      news
# 250                        news/blog/2005/dec/20/post40  article      news
# 279            news/observerblog/2006/jul/10/houseparty  article      news
# 492          news/datablog/2009/apr/28/swine-flu-mexico  article      news
# 493   news/blog/2009/may/07/northerner-x-files-scarb...  article      news
# 657        news/2011/jul/13/weatherwatch-flying-saucers  article      news
# 681   news/2011/nov/16/weatherwatch-thunderstorm-met...  article      news
# 731        news/blog/2012/nov/02/your-views-on-the-news  article      news
# 913       news/2015/mar/16/looking-back-science-fiction  article      news
# 1049  news/2017/jul/11/atmospheric-sound-channels-go...  article      news
# 1058  news/2017/sep/08/lauri-love-british-hacker-ano...  article      news
# 1080                 news/2018/apr/30/looking-back-ufos  article      news
# 1097  news/2018/aug/02/is-compassion-fatigue-inevita...  article      news
# 1210    news/2021/mar/24/corrections-and-clarifications  article      news
# 1258  news/2021/sep/07/disastrous-voyage-satoshi-cry...  article      news
#
#      sectionName        webPublicationDate  \
# 27          News 2000-01-12 01:32:02+00:00
# 115         News 2002-05-30 13:41:59+00:00
# 193         News 2004-05-20 01:44:33+00:00
# 216         News 2005-01-31 11:04:59+00:00
# 250         News 2005-12-20 11:00:04+00:00
# 279         News 2006-07-10 12:00:11+00:00
# 492         News 2009-04-28 12:44:04+00:00
# 493         News 2009-05-07 16:10:12+00:00
# 657         News 2011-07-13 22:01:01+00:00
# 681         News 2011-11-16 22:30:00+00:00
# 731         News 2012-11-02 16:58:54+00:00
# 913         News 2015-03-16 15:30:10+00:00
# 1049        News 2017-07-11 20:30:05+00:00
# 1097  https://content.guardianapis.com/news/2018/aug...     False
# 1210  https://content.guardianapis.com/news/2021/mar...     False
# 1258  https://content.guardianapis.com/news/2021/sep...     False
#
#          pillarId pillarName
# 27    pillar/news       News
# 115   pillar/news       News
# 193   pillar/news       News
# 216   pillar/news       News
# 250   pillar/news       News
# 279   pillar/news       News
# 492   pillar/news       News
# 493   pillar/news       News
# 657   pillar/news       News
# 681   pillar/news       News
# 731   pillar/news       News
# 913   pillar/news       News
# 1049  pillar/news       News
# 1058  pillar/news       News
# 1080  pillar/news       News
# 1097  pillar/news       News
# 1210  pillar/news       News
# 1258  pillar/news       News

# %%
dn = pd.to_datetime(df['webPublicationDate'])

# %%
dn = dn.dt.strftime('%Y')

# %%
dn
# Out:
# 0       1989
# 1       1998
# 2       1999
# 3       1999
# 4       1999
#         ...
# 1258    2021
# 1259    2021
# 1260    2021
# 1261    2021
# 1262    2021
# Name: webPublicationDate, Length: 1263, dtype: object

# %%
type(dn)
# Out:
# pandas.core.series.Series

# %%
pd.to_datetime(df['webPublicationDate'])[2].year
# Out:
# 1999

# %%
dp = pd.DataFrame(dn)

# %%
dp['number of publications'] = 1

# %%
dp
# Out:
#      webPublicationDate  number of publications
# 0                  1989                       1
# 1                  1998                       1
# 2                  1999                       1
# 3                  1999                       1
# 4                  1999                       1
# ...                 ...                     ...
# 1258               2021                       1
# 1259               2021                       1
# 1260               2021                       1
# 1261               2021                       1
# 1262               2021                       1
#
# [1263 rows x 2 columns]

# %% [markdown]
# https://stackoverflow.com/questions/30379789/plot-pandas-data-frame-with-year-over-year-data

# %% [markdown]
# https://stackoverflow.com/questions/38621652/pandas-pivot-time-series-by-year

# %%
import numpy as np
tb = pd.pivot_table(dp, index='webPublicationDate', values='number of publications', aggfunc=np.sum)

# %%
tb
# Out:
#                     number of publications
# webPublicationDate
# 1989                                     1
# 1998                                     1
# 1999                                    25
# 2000                                    43
# 2001                                    32
# 2002                                    41
# 2003                                    39
# 2004                                    30
# 2005                                    41
# 2006                                    49
# 2007                                    58
# 2008                                    95
# 2009                                    95
# 2010                                    63
# 2011                                    73
# 2012                                    63
# 2013                                    98
# 2014                                    56
# 2015                                    56
# 2016                                    65
# 2017                                    45
# 2018                                    52
# 2019                                    33
# 2020                                    47
# 2021                                    62

# %%
tb.plot()
# Out:
# <AxesSubplot:xlabel='webPublicationDate'>

# %%
tb.plot.bar()
# Out:
# <AxesSubplot:xlabel='webPublicationDate'>

# %%
dn.hist()
# Out:
# <AxesSubplot:>

# %%
dp
# Out:
#      webPublicationDate  number of publications
# 0                  1989                       1
# 1                  1998                       1
# 2                  1999                       1
# 3                  1999                       1
# 4                  1999                       1
# ...                 ...                     ...
# 1258               2021                       1
# 1259               2021                       1
# 1260               2021                       1
# 1261               2021                       1
# 1262               2021                       1
#
# [1263 rows x 2 columns]
