# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import matplotlib.pyplot as plt
import matplotlib.lines as mlines
import numpy as np

# %%
font = {'family': 'Verdana',
        'weight': 'normal'}
rc('font', **font)

# %%
human = np.zeros((1000,1))
tea = np.zeros((500,1))
coffe = np.zeros((500,1))
for i in range(len(human)):
    human[i] = np.random.normal(.2,.2,1)
for i in range(len(tea)):
    coffe[i] = np.random.normal(.2,.2,1)
    tea[i]= np.random.normal(.2,.2,1)

# %% [markdown]
# Снова чай против кофе

# %%
fig, ax = plt.subplots()
#ax.plot(human,'ro')
ax.plot(tea,'go')
ax.plot(coffe,'go')
ax.set_title(u'без поляризации мнений')
#ax.set_xlim([-10000, 140000])
#fig, ax
# Out:
# Text(0.5, 1.0, 'без поляризации мнений')

# %%
fig, ax = plt.subplots()
#ax.plot(human,'ro')
ax.plot(tea,'bo')
ax.plot(coffe,'ro')
#ax.set_xlim([-10000, 140000])
fig, ax
# Out:
# (<Figure size 432x288 with 1 Axes>, <AxesSubplot:>)

# %%
for i in range(len(tea)):
    coffe[i] = np.random.normal(.5,.2,1)
    tea[i]= np.random.normal(-.5,.2,1)

# %%
fig, ax = plt.subplots()
#ax.plot(human,'ro')
ax.plot(tea,'bo')
ax.plot(coffe,'ro')
ax.hlines(0, 0, 500,'k')
ax.set_title(u'Поляризация мнений - чай vs кофе')
ax.annotate(u"Линия равновесия",xy=[350,0], xytext=(350, 1.2), arrowprops=dict(facecolor='black', shrink=0.05),)
# Out:
# Text(350, 1.2, 'Линия равновесия')

# %%
cats = [],[]
dogs = [],[]

for i in range(500):
    cats[0].append(np.random.normal(0,.2,1))
    cats[1].append(i)

# %%
fig, ax = plt.subplots()
#ax.plot(human,'ro')
#ax.plot(tea,'bo',coffe,'ro',cats,'g^')
ax.plot(cats,'g^')

ax.hlines(0, 0, 500,'k')
ax.set_title(u'Поляризация мнений - чай vs кофе')
ax.annotate(u"Линия равновесия",xy=[350,0], xytext=(350, 1.2), arrowprops=dict(facecolor='black', shrink=0.05),)
# Out:
# Text(350, 1.2, 'Линия равновесия')

# %%
num = 1000
step = 2 / float(num)
animals_x = []
animals_y = []
for i in range(num):
    animals_x.append(-1+step*i)
    animals_y.append(np.random.normal(0,.2))


fig, ax = plt.subplots()
ax.scatter(animals_x,animals_y)
ax.set_xlim(-1,1)
ax.set_ylim(-1,1)
ax.hlines(0, -1, 1,'y',lw=4)
ax.set_ylabel(u'Отношение к предмету')
ax.set_xlabel(u'Пользователи')
ax.set_title(u'Нормальное распределение')
ax.annotate(u"Линия равновесия",xy=[0.9,0], xytext=(.9, .9), arrowprops=dict(facecolor='y', shrink=0.05),)
# Out:
# Text(0.9, 0.9, 'Линия равновесия')

# %%
num2 = 500
step2 = 2 / float(num2)

cats_x = []
cats_y = []

for i in range(num2):
    cats_x.append(-1+step2*i)
    cats_y.append(np.random.normal(.5,.2))

dogs_x = []
dogs_y = []
for i in range(num2):
    dogs_x.append(-1+step2*i)
    dogs_y.append(np.random.normal(-.5,.2))



fig, ax = plt.subplots()
ax.scatter(dogs_x,dogs_y,c='r')
ax.scatter(cats_x,cats_y,c='b')
ax.set_xlim(-1,1)
ax.set_ylim(-1,1)
ax.hlines(0, -1, 1,'y',lw=4)
ax.set_ylabel(u'Поляризация мнений')
ax.set_xlabel(u'Пользователи')
ax.set_title(u'Нормальное распределение')
ax.annotate(u"Линия равновесия",xy=[0.9,0], xytext=(.9, .9), arrowprops=dict(facecolor='y', shrink=0.05),)
# Out:
# Text(0.9, 0.9, 'Линия равновесия')

# %%
num = 1000
step = 2 / float(num)
drink_x = []
drink_y = []
for i in range(num):
    drink_x.append(np.random.normal(0,.2))
    drink_y.append(-1+step*i)


fig, ax = plt.subplots()
ax.scatter(drink_x,drink_y,c='c')
ax.set_xlim(-1,1)
ax.set_ylim(-1,1)
ax.vlines(0, -1, 1,'y',lw=4)
ax.set_xlabel(u'Отношение к предмету')
ax.set_ylabel(u'Пользователи')
ax.set_title(u'Нормальное распределение для другой категории')
ax.annotate(u"Линия равновесия",xy=[0,0.9], xytext=(.9, .9), arrowprops=dict(facecolor='y', shrink=0.05),)
# Out:
# Text(0.9, 0.9, 'Линия равновесия')

# %%
num = 500
step = 2 / float(num)
tea_x = []
tea_y = []
for i in range(num):
    tea_x.append(np.random.normal(-.7,.2))
    tea_y.append(-1+step*i)

coffe_x = []
coffe_y = []
for i in range(num):
    coffe_x.append(np.random.normal(.7,.2))
    coffe_y.append(-1+step*i)

fig, ax = plt.subplots()
ax.scatter(tea_x,tea_y,c='c')
ax.scatter(coffe_x,coffe_y,c='m')
ax.set_xlim(-1,1)
ax.set_ylim(-1,1)

ax.set_xlabel(u'Отношение к предмету')
ax.set_ylabel(u'Пользователи')
ax.set_title(u'Поляризация отношения')

ax.vlines(0, -1, 1,'g',lw=4)
ax.annotate(u"Линия равновесия",xy=[0,0.9], xytext=(.9, .9), arrowprops=dict(facecolor='g', shrink=0.05),)
# Out:
# Text(0.9, 0.9, 'Линия равновесия')

# %%
num2 = 500
step2 = 2 / float(num2)

cats_x = []
cats_y = []

for i in range(num2):
    cats_x.append(-1+step2*i)
    cats_y.append(np.random.normal(.5,.2))

dogs_x = []
dogs_y = []
for i in range(num2):
    dogs_x.append(-1+step2*i)
    dogs_y.append(np.random.normal(-.5,.2))


tea_x = []
tea_y = []
for i in range(num):
    tea_x.append(np.random.normal(-.7,.2))
    tea_y.append(-1+step*i)

coffe_x = []
coffe_y = []
for i in range(num):
    coffe_x.append(np.random.normal(.7,.2))
    coffe_y.append(-1+step*i)

fig, ax = plt.subplots()
ax.scatter(dogs_x,dogs_y,c='r')
ax.scatter(cats_x,cats_y,c='b')
ax.scatter(tea_x,tea_y,c='c')
ax.scatter(coffe_x,coffe_y,c='m')
ax.set_xlim(-1,1)
ax.set_ylim(-1,1)

ax.vlines(0, -1, 1,'g',lw=4)
ax.hlines(0, -1, 1,'y',lw=4)

ax.annotate(u"Центр симметрии групп",xy=[0,0], xytext=(1.2, 1.2), arrowprops=dict(facecolor='r', shrink=0.05),)
# Out:
# Text(1.2, 1.2, 'Центр симметрии групп')

# %%
num2 = 500
step2 = 2 / float(num2)

cats_x = []
cats_y = []

for i in range(num2):
    cats_x.append(-1+step2*i)
    cats_y.append(np.random.normal(.5,.1))

dogs_x = []
dogs_y = []
for i in range(num2):
    dogs_x.append(-1+step2*i)
    dogs_y.append(np.random.normal(-.5,.1))


tea_x = []
tea_y = []
for i in range(num):
    tea_x.append(np.random.normal(-.7,.1))
    tea_y.append(-1+step*i)

coffe_x = []
coffe_y = []
for i in range(num):
    coffe_x.append(np.random.normal(.7,.1))
    coffe_y.append(-1+step*i)

    
circle1 = plt.Circle((.7, -.5), 0.2, color='b', fill=False,lw=4)
circle2 = plt.Circle((-.7, -.5), 0.2, color='r', fill=False,lw=4)
circle3 = plt.Circle((-.7, .5), 0.2, color='c', fill=False,lw=4)
circle4 = plt.Circle((.7, .5), 0.2, color='g', fill=False,lw=4)

    
fig, ax = plt.subplots()
ax.scatter(dogs_x,dogs_y,c='r')
ax.scatter(cats_x,cats_y,c='b')
ax.scatter(tea_x,tea_y,c='c')
ax.scatter(coffe_x,coffe_y,c='m')

ax.add_artist(circle1)
ax.add_artist(circle2)
ax.add_artist(circle3)
ax.add_artist(circle4)



ax.set_xlim(-1,1)
ax.set_ylim(-1,1)

ax.vlines(0, -1, 1,'g',lw=4)
ax.hlines(0, -1, 1,'y',lw=4)

ax.scatter([-.75],[.5],c='r',linewidths=4)
ax.scatter([.75],[-.5],c='r',linewidths=4)
#ax. ([-.75,.5],[.75,-.5])

ax.annotate(u"Центр симметрии групп",xy=[0,0], xytext=(1.2, 1.2), arrowprops=dict(facecolor='r', shrink=0.05),)
# Out:
# Text(1.2, 1.2, 'Центр симметрии групп')

# %%
num2 = 500
step2 = 2 / float(num2)

   
circle1 = plt.Circle((.7, -.5), 0.2, color='b', fill=False,lw=4)
circle2 = plt.Circle((-.7, -.5), 0.2, color='r', fill=False,lw=4)
circle3 = plt.Circle((-.7, .5), 0.2, color='c', fill=False,lw=4)
circle4 = plt.Circle((.7, .5), 0.2, color='g', fill=False,lw=4)

line = mlines.Line2D([-.75,.75],[.5,-.5])
    
fig, ax = plt.subplots()

ax.add_artist(circle1)
ax.add_artist(circle2)
ax.add_artist(circle3)
ax.add_artist(circle4)

ax.set_xlim(-1,1)
ax.set_ylim(-1,1)

#ax.vlines(0, -1, 1,'g',lw=4)
#ax.hlines(0, -1, 1,'y',lw=4)

ax.scatter([-.75],[.5],c='r',linewidths=4)
ax.scatter([.75],[-.5],c='r',linewidths=4)
ax.add_line(line)


#ax.annotate(u"Центр симметрии групп",xy=[0,0], xytext=(1.2, 1.2), arrowprops=dict(facecolor='r', shrink=0.05),)

# %%
num2 = 500
step2 = 2 / float(num2)

   
#circle1 = plt.Circle((.7, -.5), 0.2, color='b', fill=False,lw=4)
circle2 = plt.Circle((-.7, -.5), 0.2, color='r', fill=False,lw=4)
circle3 = plt.Circle((-.7, .5), 0.2, color='c', fill=False,lw=4)
circle4 = plt.Circle((.7, .5), 0.2, color='g', fill=False,lw=4)

line = mlines.Line2D([-.75,.75],[.5,-.5])
    
fig, ax = plt.subplots()

#ax.add_artist(circle1)
ax.add_artist(circle2)
ax.add_artist(circle3)
ax.add_artist(circle4)

ax.set_xlim(-1,1)
ax.set_ylim(-1,1)

#ax.vlines(0, -1, 1,'g',lw=4)
#ax.hlines(0, -1, 1,'y',lw=4)

ax.scatter([-.75],[.5],c='r',linewidths=4)
ax.scatter([.75],[-.5],c='r',linewidths=4)
ax.add_line(line)


ax.annotate(u"Что если симметричной группы нет?",xy=[.8,-.5], xytext=(1.1, -.5), arrowprops=dict(facecolor='r', shrink=0.05),)
# Out:
# Text(1.1, -0.5, 'Что если симметричной группы нет?')
