# %%
# %pylab inline
import scipy as sc
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Пишем функцию для определения случайного времени.
#
# Как работает нормальное распределение?

# %%
s = np.random.normal(0, .1, 1000)
t = np.random.rand(1000)
plot(t,'bo',s,'ro')
# Out:
# [<matplotlib.lines.Line2D at 0x7fe47885f9e8>,
#  <matplotlib.lines.Line2D at 0x7fe47885fb00>]

# %% [markdown]
# Обрати внимание - оно будет группироваться вокруг "полюса" - нулевого значения. Со средней толщиной полосы около двух сигм. То есть, если сигму задать в .5, она распределится по 1?

# %%
import scipy.stats

s = np.random.normal(0, .5, 1000)
t = np.random.rand(1000)
plot(t,'bo',s,'ro')
plt.show() # для двух графиков сразу
fit = sc.stats.norm.pdf(s, np.mean(s), np.std(s))  #this is a fitting indeed

# %% [markdown]
# На что влияет мю? задается normal(mu,sigma,n) - то есть мю это -
# среднее.

# %%
s = np.random.normal(1, .1, 1000)
t = np.random.rand(1000)
plot(t,'bo',s,'ro')
# Out:
# [<matplotlib.lines.Line2D at 0x7fe3f955d7b8>,
#  <matplotlib.lines.Line2D at 0x7fe3f955d860>]

# %% [markdown]
# Обратите внимание, что время может быть придется отсеивать по отрицательным величинам - некоторые результаты может "забрасывать" за ноль.

# %%
s = np.random.weibull(1.,1000)
t = np.random.rand(1000)
plot(t,'bo',s,'ro')
# Out:
# [<matplotlib.lines.Line2D at 0x7fe3f94d84e0>,
#  <matplotlib.lines.Line2D at 0x7fe3f94d8588>]

# %%
s = 2 - np.random.weibull(1.,1000)
t = np.random.rand(1000)
plot(t,'bo',s,'ro')
# Out:
# [<matplotlib.lines.Line2D at 0x7fe3f9453908>,
#  <matplotlib.lines.Line2D at 0x7fe3f9453940>]

# %%
s = np.random.poisson(1.,1000)
t = np.random.rand(1000)
plot(t,'bo',s,'ro')
# Out:
# [<matplotlib.lines.Line2D at 0x7fe3f93cfbe0>,
#  <matplotlib.lines.Line2D at 0x7fe3f93cfc18>]

# %%
s = np.random.weibull(4., 1000)
t = np.random.rand(1000)
plot(t,'bo',s,'ro')
# Out:
# [<matplotlib.lines.Line2D at 0x7fe3f93c9e10>,
#  <matplotlib.lines.Line2D at 0x7fe3f93c9eb8>]

# %%
s = np.random.weibull(5., 1000)
t = np.random.rand(1000)
plot(t,'bo',s,'ro')
# Out:
# [<matplotlib.lines.Line2D at 0x7fe3f9344da0>,
#  <matplotlib.lines.Line2D at 0x7fe3f9344e48>]

# %%
s_w = np.random.weibull(5., 1000)*1000
t = np.random.rand(1000)*1000
plot(t,'bo',s_w,'ro')
# Out:
# [<matplotlib.lines.Line2D at 0x7fe3f92ca978>,
#  <matplotlib.lines.Line2D at 0x7fe3f92caa20>]

# %%
s_w = np.random.exponential(1, 1000)
t = np.random.rand(1000)
plot(t,'bo',s_w,'ro')
# Out:
# [<matplotlib.lines.Line2D at 0x7fe3f9248dd8>,
#  <matplotlib.lines.Line2D at 0x7fe3f9248e80>]

# %%
print(max(s_w), min(s_w), median(s_w))
# Out:
# 6.784992162755784 0.00012338015604258052 0.6917728239611727
