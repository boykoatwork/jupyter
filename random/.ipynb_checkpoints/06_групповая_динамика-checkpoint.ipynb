# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import random
import math

# %%
x = []
for i in range(100):
    x.append(random.random())

# %%
y = []
for i in range(len(x)):
    y.append(math.sqrt(x[i] * 2 / 0.001))

# %%
plot(y)

# %%
min(y)
# Out:
# 2.3508210396092424

# %%
max(y)
# Out:
# 44.606713809130945

# %%
median(y)
# Out:
# 32.677873603546907

# %% [markdown]
# Думаем как?
#
# Есть промежуток времени $\Delta t$ есть функция, которая определяет распределение вероятности на промежутке.
#
# Как единичным жребием определить насколько функция может выйти из строя? Бред.
#
# $$ a = \frac{i}{2} $$

# %%
>>> mu, sigma = 0, 0.1 # mean and standard deviation
>>> s = np.random.normal(mu, sigma, 1000)
>>> z = np.zeros(1000)
>>> o = np.ones(1000)

# %%
plot(s, o, "+")

# %%
plot(s,"o")

# %%
plot(s, z, "o")

# %% [markdown]
# Это все хорошо, но мне нужно... что мне нужно? Мне нужен генератор T отказов на t времени. Хорошо. В каких пределах? Допустим... допустим, что есть $T_ср$ - и отсюда уже можно танцевать.

# %%
import random as rnd

get_ipython().magic(u'matplotlib inline')


a  = []
b = []
y = 0
for i in range(7):
	y = int(rnd.random()*100+1900)
	delta = int(rnd.random()*100)
	a.append(y)
	b.append(y+delta)


fig = plt.figure()
plt.hlines(range(len(a)),a,b)

# %%
s = np.random.normal(0, .1, 1000) * 100+50
t = np.random.rand(1000)*100
plot(t,'bo',s,'ro')
# Out:
# [<matplotlib.lines.Line2D at 0x7f1c462e5750>,
#  <matplotlib.lines.Line2D at 0x7f1c462e5890>]

# %%
s = np.random.normal(0, .1, 1000) * 100+50
t = np.random.rand(1000)*100
plot(t,'bo',s,'ro')
# Out:
# [<matplotlib.lines.Line2D at 0x7f1c46217390>,
#  <matplotlib.lines.Line2D at 0x7f1c462174d0>]

# %% [markdown]
# # Либералы и демократы

# %%
pol = np.random.normal(0, .2, 1000)
plot(pol,'go',label='test1')
#plt.xlabel('Foo')
plt.ylabel(u'Политики')
plt.title(u"Отдельные люди")
plt.plot([0, 1000], [0, 0], 'k-', lw=2)

# %%
pol_plus = np.random.normal(.5, .2, 500)
pol_minus = np.random.normal(-.5, .2, 500)
plot(pol_plus,'ro', pol_minus, 'bo',label=['test1','2'])
plt.ylabel(u'Politics')
plt.title(u"Polarisation: Libreal vs Democrats")
plt.plot([0, 500], [0.5, 0.5], 'k-', lw=2)
plt.plot([0, 500], [-0.5, -0.5], 'k-', lw=2)
plt.plot([0, 500], [0, 0], 'k--', lw=2)

# %%
pol_plus = np.random.normal(.5, .2, 500)
pol_minus = np.random.normal(-.5, .2, 500)
tea = np.random.normal(.5, .2, 500)
coffe = np.random.normal(-.5, .2, 500)
plot(pol_plus,tea,'ro', pol_minus,coffe, 'bo',label=['test1','2'])
plt.ylabel(u'Politics')
plt.xlabel(u'Tea vs Coffe')
plt.title(u"Polarisation: Libreal vs Democrats")

# %%
pol_plus = np.random.normal(.5, .2, 500)
pol_minus = np.random.normal(-.5, .2, 500)
tea = np.random.normal(.5, .2, 500)
coffe = np.random.normal(-.5, .2, 500)
plot(pol_plus,tea+coffe,'ro',  pol_minus,tea+coffe, 'bo',label="debm")
plt.ylabel(u'Политики')
plt.xlabel(u'Чай или Кофе')
plt.title(u"Поляризация: Либералы vs Демократы")

# %% [markdown]
# # Напитки

# %%
a = np.random.normal(0,.2,1000)
b = array(xrange(1000))

# %%
plot(a,b,'co')
plt.plot([0, 0], [0, 1000], 'k-', lw=2)

# %%
coffe = np.random.normal(-.5,.2,500)
coffe_b = array(xrange(500))/500.0 - .5
tea = np.random.normal(.5,.2,500)
tea_b = array(xrange(500))/500.0 - .5

# %%
plot(coffe,coffe_b,'yo',tea,tea_b,'mo')
plt.plot([-0.5, -0.5], [-.5, .5], 'k-', lw=2)
plt.plot([0.5, 0.5], [-.5, .5], 'k-', lw=2)
plt.plot([0, 0], [-.5, -.5], 'k--', lw=2)

# %%
cat = np.random.normal(-.5,.2,500)
cat_b = array(xrange(500))/500.0-0.5
dog = np.random.normal(.5,.2,500)
dog_b = array(xrange(500))/500.0 - 0.5

# %%
plot(coffe,coffe_b,'yo',tea,tea_b,'mo',cat_b,cat,'bo',dog_b,dog,'ro')
#plt.plot([-0.5, -0.5], [0, 500], 'k-', lw=2)
#plt.plot([0.5, 0.5], [0, 500], 'k-', lw=2)
#plt.plot([0, 0], [0, 500], 'k--', lw=2)
# Out:
# [<matplotlib.lines.Line2D at 0x7f1c45955850>,
#  <matplotlib.lines.Line2D at 0x7f1c45955950>,
#  <matplotlib.lines.Line2D at 0x7f1c45960090>,
#  <matplotlib.lines.Line2D at 0x7f1c45960690>]
