# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import random
import math

# %%
x = []
for i in range(100):
    x.append(random.random())

# %%
y = []
for i in range(len(x)):
    y.append(math.sqrt(x[i] * 2 / 0.001))

# %%
plot(y)

# %%
min(y)
# Out:
# 7.960172597205711

# %%
max(y)
# Out:
# 44.70936064648313

# %%
median(y)
# Out:
# 32.86774534692841

# %% [markdown]
# Думаем как?
#
# Есть промежуток времени $\Delta t$ есть функция, которая определяет распределение вероятности на промежутке.
#
# $$ a = \frac{i}{2} $$

# %%
>>> mu, sigma = 0, 0.1 # mean and standard deviation
>>> s = np.random.normal(mu, sigma, 1000)
>>> z = np.zeros(1000)
>>> o = np.ones(1000)

# %%
plot(s, o, "+")

# %%
plot(s,"o")

# %%
plot(s, z, "o")

# %% [markdown]
# Это все хорошо, но мне нужно... что мне нужно? Мне нужен генератор T отказов на t времени. Хорошо. В каких пределах? Допустим... допустим, что есть $T_ср$ - и отсюда уже можно танцевать.

# %%
s = np.random.normal(0, .1, 1000) * 100+50
t = np.random.rand(1000)*100
plot(t,'bo',s,'ro')
# Out:
# [<matplotlib.lines.Line2D at 0x7f9fe42b5bb0>,
#  <matplotlib.lines.Line2D at 0x7f9fe42b5be0>]

# %%
s = np.random.normal(0, .1, 1000) * 100+50
t = np.random.rand(1000)*100
plot(t,'bo',s,'ro')
# Out:
# [<matplotlib.lines.Line2D at 0x7f9fe4210820>,
#  <matplotlib.lines.Line2D at 0x7f9fe4210850>]
