# %% [markdown]
# # My apple estimator

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# apple - mass and radius

# %% [markdown]
# ## 1. Apples on asphalt

# %%
apples = []

# %% [markdown]
# ### 1.1 about normal distribution

# %% [markdown]
# ![]( ./img/2452434245-5f292a0807f98_articlex.jpg )
#
# ![]( ./img/livinghistogram.jpg)
#
#
# ![]( ./img/picture-91.png )

# %% [markdown]
# ### Apples as is

# %% [markdown]
# https://numpy.org/doc/stable/reference/random/generated/numpy.random.normal.html

# %%
edible = []

for i in range(100):
    m = 60 + np.random.normal() * 9
    r = 55 + np.random.normal() * 10
    edible.append((m,r))

# %%
x = [x[0] for x in edible]
y = [x[1] for x in edible]

plt.plot(x,y,'or')
plt.show()

# %%
non_edible = []

for i in range(100):
    m = abs(20 + np.random.normal() * 10)
    r = abs(20 + np.random.normal() * 10)
    non_edible.append((m,r))

# %%
xn,yn = [x[0] for x in non_edible], [x[1] for x in non_edible]

plt.plot(xn,yn,'ob')
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(x,y, 'ro')
ax.plot(xn, yn, 'bo')

fig, ax
# Out:
# (<Figure size 432x288 with 1 Axes>, <AxesSubplot:>)

# %%
fig, ax = plt.subplots(figsize=(8,8))
ax.plot(x,y, 'ro')
ax.plot(xn, yn, 'bo')

fig, ax
# Out:
# (<Figure size 576x576 with 1 Axes>, <AxesSubplot:>)

# %%
fig, ax = plt.subplots(figsize=(8,8))
ax.plot(x,y, 'ro')
ax.plot(xn, yn, 'bo')
ax.plot(39, 39, 'ys')
fig, ax
# Out:
# (<Figure size 576x576 with 1 Axes>, <AxesSubplot:>)

# %% [markdown]
# https://stackoverflow.com/questions/9215658/plot-a-circle-with-pyplot
#
# https://www.delftstack.com/howto/matplotlib/how-to-plot-a-circle-in-matplotlib/
#
# https://matplotlib.org/3.5.1/api/_as_gen/matplotlib.patches.Circle.html#matplotlib-patches-circle

# %%
x_new = 39
y_new = 39

fig, ax = plt.subplots(figsize=(8,8))

ax.plot(x,y, 'ro')
ax.plot(xn, yn, 'bo')
ax.plot(x_new, y_new, 'ys')

krg = plt.Circle((x_new, y_new), 10,fill=False, color ='g')

ax.add_artist(krg)
ax.set_aspect(1)


fig, ax
# Out:
# (<Figure size 576x576 with 1 Axes>, <AxesSubplot:>)

# %%
x_new = 39
y_new = 39
fig, ax = plt.subplots(figsize=(8,8))
ax.plot(x,y, 'ro')
ax.plot(xn, yn, 'bo')
ax.plot(x_new, y_new, 'ys')

krg = plt.Circle((x_new, y_new), 20,fill=False, color ='g')
ax.add_artist(krg)

ax.set_aspect(1)


fig, ax
# Out:
# (<Figure size 576x576 with 1 Axes>, <AxesSubplot:>)

# %% [markdown]
# ![]( ./img/distance.robocrop.realpython.webp)

# %% [markdown]
# ### 2. Apples and sklearn

# %%
from sklearn.neighbors import KNeighborsClassifier

# %% [markdown]
# Creating model:

# %%
model = KNeighborsClassifier(n_neighbors=3)

# %% [markdown]
# Set model on array:

# %%
edible[:3], non_edible[:3]
# Out:
# ([(73.60497203129772, 51.488948601792806),
#   (65.16503955346188, 47.4186560767843),
#   (59.80145406354114, 52.72715667943915)],
#  [(31.962447689000808, 9.034471480615256),
#   (11.792345632297742, 38.60688494933566),
#   (34.02940246670393, 19.358933740647874)])

# %%
apples = [] # список объектов (координаты)
labels = [] # список классов объектов

for i in edible:
    apples.append(i)
    labels.append(1)

for j in non_edible:
    apples.append(j)
    labels.append(0)

# %%
apples[98:102]
# Out:
# [(59.0971322627804, 40.20776471245041),
#  (66.75607039068377, 49.99313750447978),
#  (31.962447689000808, 9.034471480615256),
#  (11.792345632297742, 38.60688494933566)]

# %%
labels[98:102]
# Out:
# [1, 1, 0, 0]

# %%
# Train the model using the training sets
model.fit(apples,labels)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %% [markdown]
# ### Classification

# %%
#Predict Output
predicted= model.predict([[x_new,y_new]])
print(predicted)
# Out:
# [0]

# %%
x_new = 50
y_new = 55
fig, ax = plt.subplots(figsize=(8,8))
ax.plot(x,y, 'ro')
ax.plot(xn, yn, 'bo')
ax.plot(x_new, y_new, 'ys')

krg = plt.Circle((x_new, y_new), 20,fill=False, color ='g')
ax.add_artist(krg)

ax.set_aspect(1)


fig, ax
# Out:
# (<Figure size 576x576 with 1 Axes>, <AxesSubplot:>)

# %%
#Predict Output
predicted= model.predict([[x_new,y_new]])
print(predicted)
# Out:
# [1]

# %% [markdown]
# ![](./img/naylor.jpg)

# %% [markdown]
# ![](./img/Нейлор1991.png)

# %% [markdown]
# Further reading
#
# - [K-Nearest Neighbor Algorithm in various real World Cases](https://medium.com/analytics-vidhya/k-nearest-neighbor-algorithm-in-various-real-world-cases-113c1dc75e91)

# %% [markdown]
# Classification vs Regression
#
# - [Classification vs Regression](https://realpython.com/knn-python/#knn-is-a-supervised-learner-for-both-classification-and-regression)
