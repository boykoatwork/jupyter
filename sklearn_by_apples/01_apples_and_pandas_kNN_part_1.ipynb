# %% [markdown]
# ## Apples and Pandas - generating data

# %%
import numpy as np
import pandas as pd

# %%
apples = []

# %% [markdown]
# https://numpy.org/doc/stable/reference/random/generated/numpy.random.normal.html

# %%
edible = []
non_edible = []

for i in range(100):
    m = 60 + np.random.normal() * 9
    r = 55 + np.random.normal() * 10
    edible.append((m,r))

# %%
ap = pd.DataFrame(edible)

# %%
ap.head(5)
# Out:
#            0          1
# 0  61.048207  52.273946
# 1  56.839866  62.298942
# 2  72.426606  47.707997
# 3  56.197415  51.448994
# 4  49.700877  55.485233

# %% [markdown]
# https://dataindependent.com/pandas/pandas-change-column-names-3-methods/

# %%
ap.columns = ["mass", "radius"]

# %%
ap.head()
# Out:
#         mass     radius
# 0  61.048207  52.273946
# 1  56.839866  62.298942
# 2  72.426606  47.707997
# 3  56.197415  51.448994
# 4  49.700877  55.485233

# %%
ap["edible"] = 1

# %%
ap
# Out:
#          mass     radius  edible
# 0   61.048207  52.273946       1
# 1   56.839866  62.298942       1
# 2   72.426606  47.707997       1
# 3   56.197415  51.448994       1
# 4   49.700877  55.485233       1
# ..        ...        ...     ...
# 95  55.058522  46.965417       1
# 96  52.384690  52.854752       1
# 97  71.678984  49.528258       1
# 98  50.388414  70.562763       1
# 99  40.553318  50.295120       1
#
# [100 rows x 3 columns]

# %%
non_edible = []

# %%
for i in range(100):
    m = abs(20 + np.random.normal() * 10)
    r = abs(20 + np.random.normal() * 10)
    non_edible.append((m,r))

# %%
non_edible = pd.DataFrame( 
    {'mass': [abs(20 + np.random.normal() * 10) for i in range(100) ],
     'radius': [abs(20 + np.random.normal() * 10) for i in range(100)],
     'edible' : 0 }
)

# %%
non_edible
# Out:
#          mass     radius  edible
# 0    8.217680  34.747447       0
# 1   33.884258  30.891673       0
# 2    5.935603  32.650663       0
# 3    5.138589  24.389922       0
# 4   39.747696  31.758503       0
# ..        ...        ...     ...
# 95  38.613118  34.660654       0
# 96   7.557590  12.398003       0
# 97  36.712169  20.425777       0
# 98  10.519998  35.015751       0
# 99  23.395543  21.118617       0
#
# [100 rows x 3 columns]

# %% [markdown]
# https://www.geeksforgeeks.org/python-pandas-dataframe-append/
#
# https://datacarpentry.org/python-ecology-lesson/05-merging-data/

# %%
ap = pd.concat([ap, non_edible])

# %%
ap
# Out:
#          mass     radius  edible
# 0   61.048207  52.273946       1
# 1   56.839866  62.298942       1
# 2   72.426606  47.707997       1
# 3   56.197415  51.448994       1
# 4   49.700877  55.485233       1
# ..        ...        ...     ...
# 95  38.613118  34.660654       0
# 96   7.557590  12.398003       0
# 97  36.712169  20.425777       0
# 98  10.519998  35.015751       0
# 99  23.395543  21.118617       0
#
# [200 rows x 3 columns]

# %%
ap.to_csv('data/apples.csv')

# %%
# !rm 'data/apples.sqlite' -rf

import sqlite3

conn = sqlite3.connect('data/apples.sqlite')

ap.to_sql('apples', conn)
conn.close()
