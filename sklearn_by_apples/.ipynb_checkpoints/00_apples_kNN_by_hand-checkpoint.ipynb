# %% [markdown]
# # My apple estimator

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# apple - mass and radius

# %% [markdown]
# ## 1. Apples on asphalt

# %%
apples = []

# %% [markdown]
# ### 1.1 about normal distribution

# %% [markdown]
# ![]( ./img/2452434245-5f292a0807f98_articlex.jpg )
#
# ![]( ./img/livinghistogram.jpg)
#
#
# ![]( ./img/picture-91.png )

# %% [markdown]
# ### Apples as is

# %% [markdown]
# https://numpy.org/doc/stable/reference/random/generated/numpy.random.normal.html

# %%
edible = []
non_edible = []

for i in range(100):
    m = 60 + np.random.normal() * 9
    r = 55 + np.random.normal() * 10
    edible.append((m,r))

# %%
x = [x[0] for x in edible]
y = [x[1] for x in edible]

plt.plot(x,y,'or')
plt.show()

# %%
non_edible = []

for i in range(100):
    m = abs(20 + np.random.normal() * 10)
    r = abs(20 + np.random.normal() * 10)
    non_edible.append((m,r))

# %%
xn,yn = [x[0] for x in non_edible], [x[1] for x in non_edible]

plt.plot(xn,yn,'ob')
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(x,y, 'ro')
ax.plot(xn, yn, 'bo')

fig, ax
# Out:
# (<Figure size 432x288 with 1 Axes>, <AxesSubplot:>)

# %%
fig, ax = plt.subplots(figsize=(8,8))
ax.plot(x,y, 'ro')
ax.plot(xn, yn, 'bo')

fig, ax
# Out:
# (<Figure size 576x576 with 1 Axes>, <AxesSubplot:>)

# %%
fig, ax = plt.subplots(figsize=(8,8))
ax.plot(x,y, 'ro')
ax.plot(xn, yn, 'bo')
ax.plot(39, 39, 'ys')
fig, ax
# Out:
# (<Figure size 576x576 with 1 Axes>, <AxesSubplot:>)

# %% [markdown]
# https://stackoverflow.com/questions/9215658/plot-a-circle-with-pyplot
#
# https://www.delftstack.com/howto/matplotlib/how-to-plot-a-circle-in-matplotlib/
#
# https://matplotlib.org/3.5.1/api/_as_gen/matplotlib.patches.Circle.html#matplotlib-patches-circle

# %%
x_new = 39
y_new = 39
fig, ax = plt.subplots(figsize=(8,8))
ax.plot(x,y, 'ro')
ax.plot(xn, yn, 'bo')
ax.plot(x_new, y_new, 'ys')

krg = plt.Circle((x_new, y_new), 10,fill=False, color ='g')
ax.add_artist(krg)

ax.set_aspect(1)


fig, ax
# Out:
# (<Figure size 576x576 with 1 Axes>, <AxesSubplot:>)

# %%
x_new = 39
y_new = 39
fig, ax = plt.subplots(figsize=(8,8))
ax.plot(x,y, 'ro')
ax.plot(xn, yn, 'bo')
ax.plot(x_new, y_new, 'ys')

krg = plt.Circle((x_new, y_new), 20,fill=False, color ='g')
ax.add_artist(krg)

ax.set_aspect(1)


fig, ax
# Out:
# (<Figure size 576x576 with 1 Axes>, <AxesSubplot:>)

# %% [markdown]
# ### 2. Apples and sklearn

# %%
from sklearn.neighbors import KNeighborsClassifier

# %% [markdown]
# Creating model:

# %%
model = KNeighborsClassifier(n_neighbors=3)

# %% [markdown]
# Set model on array:

# %%
edible[:3], non_edible[:3]
# Out:
# ([(57.92560355001683, 59.533056848893025),
#   (55.64280213995358, 54.684382206335805),
#   (59.57404074590091, 46.702600201942104)],
#  [(34.424957250597835, 23.57864578247754),
#   (11.65749225006353, 24.093409380401965),
#   (38.60563080791404, 25.612684752872795)])

# %%
apples = []
labels = []
for i in edible:
    apples.append(i)
    labels.append(1)

for j in non_edible:
    apples.append(j)
    labels.append(0)
    
apples[98:102],labels[98:102]
# Out:
# ([(82.70892279953199, 64.48056837687844),
#   (35.06134448009247, 55.52629169553213),
#   (34.424957250597835, 23.57864578247754),
#   (11.65749225006353, 24.093409380401965)],
#  [1, 1, 0, 0])

# %%
# Train the model using the training sets
model.fit(apples,labels)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %% [markdown]
# ### Classification

# %%
#Predict Output
predicted= model.predict([[x_new,y_new]])
print(predicted)
# Out:
# [1]

# %%
x_new = 50
y_new = 55
fig, ax = plt.subplots(figsize=(8,8))
ax.plot(x,y, 'ro')
ax.plot(xn, yn, 'bo')
ax.plot(x_new, y_new, 'ys')

krg = plt.Circle((x_new, y_new), 20,fill=False, color ='g')
ax.add_artist(krg)

ax.set_aspect(1)


fig, ax
# Out:
# (<Figure size 576x576 with 1 Axes>, <AxesSubplot:>)

# %%
#Predict Output
predicted= model.predict([[x_new,y_new]])
print(predicted)
# Out:
# [1]
