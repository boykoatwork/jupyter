# %% [markdown]
# ## Apples and Pandas - generating data

# %%
import numpy as np
import pandas as pd

# %%
apples = []

# %% [markdown]
# https://numpy.org/doc/stable/reference/random/generated/numpy.random.normal.html

# %%
edible = []
non_edible = []

for i in range(100):
    m = 60 + np.random.normal() * 9
    r = 55 + np.random.normal() * 10
    edible.append((m,r))

# %%
ap = pd.DataFrame(edible)

# %%
ap.head(5)
# Out:
#            0          1
# 0  49.767109  38.409585
# 1  61.329582  57.718862
# 2  65.732984  70.069895
# 3  50.682548  50.135347
# 4  57.983984  48.884216

# %% [markdown]
# https://dataindependent.com/pandas/pandas-change-column-names-3-methods/

# %%
ap.columns = ["mass", "radius"]

# %%
ap.head()
# Out:
#         mass     radius
# 0  49.767109  38.409585
# 1  61.329582  57.718862
# 2  65.732984  70.069895
# 3  50.682548  50.135347
# 4  57.983984  48.884216

# %%
ap["edible"] = 1

# %%
ap
# Out:
#          mass     radius  edible
# 0   49.767109  38.409585       1
# 1   61.329582  57.718862       1
# 2   65.732984  70.069895       1
# 3   50.682548  50.135347       1
# 4   57.983984  48.884216       1
# ..        ...        ...     ...
# 95  61.418266  44.215614       1
# 96  80.900287  54.294596       1
# 97  68.725739  56.861354       1
# 98  55.676532  30.415415       1
# 99  55.874735  70.849043       1
#
# [100 rows x 3 columns]

# %%
non_edible = []

# %%
for i in range(100):
    m = abs(20 + np.random.normal() * 10)
    r = abs(20 + np.random.normal() * 10)
    non_edible.append((m,r))

# %%
non_edible = pd.DataFrame( 
    {'mass': [abs(20 + np.random.normal() * 10) for i in range(100) ],
     'radius': [abs(20 + np.random.normal() * 10) for i in range(100)],
     'edible' : 0 }
)

# %%
non_edible
# Out:
#          mass     radius  edible
# 0   19.135432  25.122211       0
# 1   20.714437  25.078571       0
# 2   21.401454  18.801797       0
# 3   23.691379  19.705523       0
# 4   15.218722  24.914373       0
# ..        ...        ...     ...
# 95   1.985002  21.793944       0
# 96  57.353986  14.652801       0
# 97  25.143146  17.235282       0
# 98  19.238072  21.485768       0
# 99   7.613735  18.770054       0
#
# [100 rows x 3 columns]

# %% [markdown]
# https://www.geeksforgeeks.org/python-pandas-dataframe-append/
#
# https://datacarpentry.org/python-ecology-lesson/05-merging-data/

# %%
ap = pd.concat([ap, non_edible])

# %%
ap
# Out:
#          mass     radius  edible
# 0   49.767109  38.409585       1
# 1   61.329582  57.718862       1
# 2   65.732984  70.069895       1
# 3   50.682548  50.135347       1
# 4   57.983984  48.884216       1
# ..        ...        ...     ...
# 95   1.985002  21.793944       0
# 96  57.353986  14.652801       0
# 97  25.143146  17.235282       0
# 98  19.238072  21.485768       0
# 99   7.613735  18.770054       0
#
# [200 rows x 3 columns]

# %%
ap.to_csv('data/apples.csv')

# %%
# !rm 'data/apples.sqlite' -rf

import sqlite3

conn = sqlite3.connect('data/apples.sqlite')

ap.to_sql('apples', conn)
conn.close()
