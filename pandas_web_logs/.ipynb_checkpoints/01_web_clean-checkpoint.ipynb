# %%
import pandas as pd

# %%
pd.read_csv('data/access-log')
# Out:
#      140.180.132.213 - - [24/Feb/2008:00:08:59 -0600] "GET /ply/ply.html HTTP/1.1" 200 97238
# 0     140.180.132.213 - - [24/Feb/2008:00:08:59 -060...
# 1     75.54.118.139 - - [24/Feb/2008:00:15:40 -0600]...
# 2     75.54.118.139 - - [24/Feb/2008:00:15:41 -0600]...
# 3     75.54.118.139 - - [24/Feb/2008:00:15:42 -0600]...
# 4     75.54.118.139 - - [24/Feb/2008:00:15:49 -0600]...
# ...                                                 ...
# 7292  80.161.85.77 - - [29/Feb/2008:07:47:40 -0600] ...
# 7293  156.63.68.202 - - [29/Feb/2008:07:49:28 -0600]...
# 7294  156.63.68.202 - - [29/Feb/2008:07:49:28 -0600]...
# 7295  156.63.68.202 - - [29/Feb/2008:07:49:28 -0600]...
# 7296  80.161.85.77 - - [29/Feb/2008:07:52:46 -0600] ...
#
# [7297 rows x 1 columns]

# %%
pd.read_csv('data/access-log', delimiter = ' ', index_col=False, names=['ip', '1', '2', 'date', 'tz', 'req', 'status', 'bytes'])
# Out:
#                    ip  1  2                   date      tz  \
# 0     140.180.132.213  -  -  [24/Feb/2008:00:08:59  -0600]
# 1     140.180.132.213  -  -  [24/Feb/2008:00:08:59  -0600]
# 2       75.54.118.139  -  -  [24/Feb/2008:00:15:40  -0600]
# 3       75.54.118.139  -  -  [24/Feb/2008:00:15:41  -0600]
# 4       75.54.118.139  -  -  [24/Feb/2008:00:15:42  -0600]
# ...               ... .. ..                    ...     ...
# 7293     80.161.85.77  -  -  [29/Feb/2008:07:47:40  -0600]
# 7294    156.63.68.202  -  -  [29/Feb/2008:07:49:28  -0600]
# 7295    156.63.68.202  -  -  [29/Feb/2008:07:49:28  -0600]
# 7296    156.63.68.202  -  -  [29/Feb/2008:07:49:28  -0600]
# 7297     80.161.85.77  -  -  [29/Feb/2008:07:52:46  -0600]
#
#                                      req  status  bytes
# 0             GET /ply/ply.html HTTP/1.1     200  97238
# 1              GET /favicon.ico HTTP/1.1     404    133
# 2                         GET / HTTP/1.1     200   4447
# ...

# %%
w = pd.read_csv('data/access-log', delimiter = ' ', index_col=False, names=['ip', '1', '2', 'date', 'tz', 'req', 'status', 'bytes'])

# %%
ip = w['ip']

# %%
ip.describe()
# Out:
# count             7298
# unique            1353
# top       38.98.120.84
# freq               559
# Name: ip, dtype: object

# %%
ip
# Out:
# 0       140.180.132.213
# 1       140.180.132.213
# 2         75.54.118.139
# 3         75.54.118.139
# 4         75.54.118.139
#              ...
# 7293       80.161.85.77
# 7294      156.63.68.202
# 7295      156.63.68.202
# 7296      156.63.68.202
# 7297       80.161.85.77
# Name: ip, Length: 7298, dtype: object

# %%
b = w['bytes']
pd.to_numeric(b)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/env/audit/lib/python3.9/site-packages/pandas/_libs/lib.pyx:2315, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "-"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Input In [46], in <cell line: 2>()
#       1 b = w['bytes']
# ----> 2 pd.to_numeric(b)
#
# File ~/env/audit/lib/python3.9/site-packages/pandas/core/tools/numeric.py:184, in to_numeric(arg, errors, downcast)
#     182 coerce_numeric = errors not in ("ignore", "raise")
#     183 try:
# --> 184     values, _ = lib.maybe_convert_numeric(
#     185         values, set(), coerce_numeric=coerce_numeric
#     186     )
#     187 except (ValueError, TypeError):
#     188     if errors == "raise":
#
# ...

# %%
b = pd.Series([str(i) for i in range(1000)])

# %%
b
# Out:
# 0        0
# 1        1
# 2        2
# 3        3
# 4        4
#       ...
# 995    995
# 996    996
# 997    997
# 998    998
# 999    999
# Length: 1000, dtype: object

# %%
pd.to_numeric(b)
# Out:
# 0        0
# 1        1
# 2        2
# 3        3
# 4        4
#       ...
# 995    995
# 996    996
# 997    997
# 998    998
# 999    999
# Length: 1000, dtype: int64

# %%
w[ w["status"] == 304 ]
# Out:
#                    ip  1  2                   date      tz  \
# 37    122.117.168.219  -  -  [24/Feb/2008:02:15:07  -0600]
# 38    122.117.168.219  -  -  [24/Feb/2008:02:15:07  -0600]
# 39    122.117.168.219  -  -  [24/Feb/2008:02:15:11  -0600]
# 49    122.117.168.219  -  -  [24/Feb/2008:02:22:06  -0600]
# 50    122.117.168.219  -  -  [24/Feb/2008:02:22:06  -0600]
# ...               ... .. ..                    ...     ...
# 7259     66.249.65.37  -  -  [29/Feb/2008:07:11:32  -0600]
# 7261     66.249.65.37  -  -  [29/Feb/2008:07:14:41  -0600]
# 7272     66.249.65.37  -  -  [29/Feb/2008:07:23:52  -0600]
# 7275     66.249.65.37  -  -  [29/Feb/2008:07:27:56  -0600]
# 7279     66.249.65.37  -  -  [29/Feb/2008:07:31:24  -0600]
#
#                                               req  status bytes
# 37                             GET /ply/ HTTP/1.1     304     -
# 38                 GET /ply/bookplug.gif HTTP/1.1     304     -
# ...

# %%
w[ w["bytes"] != '-']
# Out:
#                    ip  1  2                   date      tz  \
# 0     140.180.132.213  -  -  [24/Feb/2008:00:08:59  -0600]
# 1     140.180.132.213  -  -  [24/Feb/2008:00:08:59  -0600]
# 2       75.54.118.139  -  -  [24/Feb/2008:00:15:40  -0600]
# 3       75.54.118.139  -  -  [24/Feb/2008:00:15:41  -0600]
# 4       75.54.118.139  -  -  [24/Feb/2008:00:15:42  -0600]
# ...               ... .. ..                    ...     ...
# 7293     80.161.85.77  -  -  [29/Feb/2008:07:47:40  -0600]
# 7294    156.63.68.202  -  -  [29/Feb/2008:07:49:28  -0600]
# 7295    156.63.68.202  -  -  [29/Feb/2008:07:49:28  -0600]
# 7296    156.63.68.202  -  -  [29/Feb/2008:07:49:28  -0600]
# 7297     80.161.85.77  -  -  [29/Feb/2008:07:52:46  -0600]
#
#                                      req  status  bytes
# 0             GET /ply/ply.html HTTP/1.1     200  97238
# 1              GET /favicon.ico HTTP/1.1     404    133
# 2                         GET / HTTP/1.1     200   4447
# ...

# %%
w['bytes'] = w['bytes'].str.replace('-', '0')

# %%
w[ w["status"] == 304 ]
# Out:
#                    ip  1  2                   date      tz  \
# 37    122.117.168.219  -  -  [24/Feb/2008:02:15:07  -0600]
# 38    122.117.168.219  -  -  [24/Feb/2008:02:15:07  -0600]
# 39    122.117.168.219  -  -  [24/Feb/2008:02:15:11  -0600]
# 49    122.117.168.219  -  -  [24/Feb/2008:02:22:06  -0600]
# 50    122.117.168.219  -  -  [24/Feb/2008:02:22:06  -0600]
# ...               ... .. ..                    ...     ...
# 7259     66.249.65.37  -  -  [29/Feb/2008:07:11:32  -0600]
# 7261     66.249.65.37  -  -  [29/Feb/2008:07:14:41  -0600]
# 7272     66.249.65.37  -  -  [29/Feb/2008:07:23:52  -0600]
# 7275     66.249.65.37  -  -  [29/Feb/2008:07:27:56  -0600]
# 7279     66.249.65.37  -  -  [29/Feb/2008:07:31:24  -0600]
#
#                                               req  status bytes
# 37                             GET /ply/ HTTP/1.1     304     0
# 38                 GET /ply/bookplug.gif HTTP/1.1     304     0
# ...

# %%
w['bytes_n'] = pd.to_numeric(w['bytes'])

# %%
w
# Out:
#                    ip  1  2                   date      tz  \
# 0     140.180.132.213  -  -  [24/Feb/2008:00:08:59  -0600]
# 1     140.180.132.213  -  -  [24/Feb/2008:00:08:59  -0600]
# 2       75.54.118.139  -  -  [24/Feb/2008:00:15:40  -0600]
# 3       75.54.118.139  -  -  [24/Feb/2008:00:15:41  -0600]
# 4       75.54.118.139  -  -  [24/Feb/2008:00:15:42  -0600]
# ...               ... .. ..                    ...     ...
# 7293     80.161.85.77  -  -  [29/Feb/2008:07:47:40  -0600]
# 7294    156.63.68.202  -  -  [29/Feb/2008:07:49:28  -0600]
# 7295    156.63.68.202  -  -  [29/Feb/2008:07:49:28  -0600]
# 7296    156.63.68.202  -  -  [29/Feb/2008:07:49:28  -0600]
# 7297     80.161.85.77  -  -  [29/Feb/2008:07:52:46  -0600]
#
#                                      req  status  bytes  bytes_n
# 0             GET /ply/ply.html HTTP/1.1     200  97238    97238
# 1              GET /favicon.ico HTTP/1.1     404    133      133
# ...

# %%
w['date2'] = w['date'].str.replace('[','', regex=False)

# %%
w
# Out:
#                    ip  1  2                   date      tz  \
# 0     140.180.132.213  -  -  [24/Feb/2008:00:08:59  -0600]
# 1     140.180.132.213  -  -  [24/Feb/2008:00:08:59  -0600]
# 2       75.54.118.139  -  -  [24/Feb/2008:00:15:40  -0600]
# 3       75.54.118.139  -  -  [24/Feb/2008:00:15:41  -0600]
# 4       75.54.118.139  -  -  [24/Feb/2008:00:15:42  -0600]
# ...               ... .. ..                    ...     ...
# 7293     80.161.85.77  -  -  [29/Feb/2008:07:47:40  -0600]
# 7294    156.63.68.202  -  -  [29/Feb/2008:07:49:28  -0600]
# 7295    156.63.68.202  -  -  [29/Feb/2008:07:49:28  -0600]
# 7296    156.63.68.202  -  -  [29/Feb/2008:07:49:28  -0600]
# 7297     80.161.85.77  -  -  [29/Feb/2008:07:52:46  -0600]
#
#                                      req  status  bytes  bytes_n  \
# 0             GET /ply/ply.html HTTP/1.1     200  97238    97238
# 1              GET /favicon.ico HTTP/1.1     404    133      133
# ...

# %%
w['date3'] = w['date2'].str.replace(':', ' ', 1)

# %%
w['dt'] = pd.to_datetime(w['date3'])

# %%
del w['date2']

# %%
w
# Out:
#                    ip  1  2                   date      tz  \
# 0     140.180.132.213  -  -  [24/Feb/2008:00:08:59  -0600]
# 1     140.180.132.213  -  -  [24/Feb/2008:00:08:59  -0600]
# 2       75.54.118.139  -  -  [24/Feb/2008:00:15:40  -0600]
# 3       75.54.118.139  -  -  [24/Feb/2008:00:15:41  -0600]
# 4       75.54.118.139  -  -  [24/Feb/2008:00:15:42  -0600]
# ...               ... .. ..                    ...     ...
# 7293     80.161.85.77  -  -  [29/Feb/2008:07:47:40  -0600]
# 7294    156.63.68.202  -  -  [29/Feb/2008:07:49:28  -0600]
# 7295    156.63.68.202  -  -  [29/Feb/2008:07:49:28  -0600]
# 7296    156.63.68.202  -  -  [29/Feb/2008:07:49:28  -0600]
# 7297     80.161.85.77  -  -  [29/Feb/2008:07:52:46  -0600]
#
#                                      req  status  bytes  bytes_n  \
# 0             GET /ply/ply.html HTTP/1.1     200  97238    97238
# 1              GET /favicon.ico HTTP/1.1     404    133      133
# ...
